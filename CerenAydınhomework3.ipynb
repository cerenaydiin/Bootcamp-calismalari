# %% [markdown]
# # 🎓 Titanic Veri Seti Görselleştirme Uygulamaları
# Her sorunun altında cevabınızı kodlayabilirsiniz.
# Grafiklerinizi yorumlamanız ve grafikten çıkarımlarınızı yazmanız gerekmektedir.

# %% [markdown]
# ## 🟢 Kolay Seviye

# %% [markdown]
# ### ❓ Soru: Cinsiyete göre yolcu sayısını görselleştirin. (örn. countplot veya bar chart)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df = sns.load_dataset("titanic")

sns.countplot(x="sex", data=df, palette="Blues") 
plt.xlabel("Cinsiyet") 
plt.ylabel("Yolcu") 
plt.xticks(rotation=45)
plt.tight_layout() 
plt.title("Cinsiyete göre yolcu sayısı")
plt.show()
# Out:
# C:\Users\ceren\AppData\Local\Temp\ipykernel_12648\1904917801.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="sex", data=df, palette="Blues")

# %% [markdown]
# ### ❓ Soru: "Survived" değişkeninin dağılımını çiziniz.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
sns.countplot(x='survived', data=df)
plt.title('Survived Değişkeninin Dağılımı')
plt.xlabel('Hayatta Kalma (0 = Hayır, 1 = Evet)')
plt.ylabel('Kişi Sayısı')
plt.show()

# %% [markdown]
# ### ❓ Soru: "Pclass" değişkeninin histogramını veya çubuk grafiğini oluşturun.

# %%
plt.figure(figsize=(8,5))
plt.hist(df["pclass"], bins=20, color="hotpink", edgecolor='black')
plt.title("Pclass Histogramı")
plt.xlabel("Pclass")
plt.ylabel("")
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ❓ Soru: "Age" değişkeninin histogramını çiziniz.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
sns.histplot(df['age'], bins=30, kde=False)  # bins: çubuk sayısı, kde: yoğunluk çizgisi
plt.title('Age Değişkeninin Histogramı')
plt.xlabel('Yaş')
plt.ylabel('Frekans')
plt.show()

# %% [markdown]
# ### ❓ Soru: "Fare" değişkeninin histogramını çizip açıklayınız.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.histplot(df['fare'], bins=30, kde=False)
plt.title('Fare Değişkeninin Histogramı')
plt.xlabel('Fare')
plt.ylabel('Frekans')
plt.show()

#Çubuklar sağa çarpık çoğu kişi ucuz bilet almış 
#Fare genelde sağ tarafta 0-300 arası yoğun ucuz biletler tercih edilmiş

# %% [markdown]
# ## 🟡 Orta Seviye

# %% [markdown]
# ### ❓ Soru: Cinsiyete göre yaş dağılımını karşılaştırın. (örn. boxplot, violinplot, kdeplot)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
print(df['sex'].value_counts())

plt.figure(figsize=(8,5))
sns.kdeplot(data=df, x='age', hue='sex', common_norm=False)
plt.title('Cinsiyete Göre Yaş Dağılımı (KDE Plot)')
plt.xlabel('Yaş')
plt.ylabel ('Yoğunluk')
plt.show()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ### ❓ Soru: Pclass'a göre ücret dağılımını inceleyin.

# %%
print(df[['pclass', 'fare']].dtypes)
print(df['pclass'].value_counts())
plt.figure(figsize=(10,4))
sns.boxplot(x='pclass', y='fare', data=df)
plt.title('Pclass’a Göre Ücret (Fare) Dağılımı')
plt.xlabel('Pclass (Yolcu Sınıfı)')
plt.ylabel('Fare (Ücret)')
plt.show()
# Out:
# pclass      int64
# fare      float64
# dtype: object
# pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# ### ❓ Soru: Survived’a göre yaş dağılımını inceleyin.

# %%
plt.figure(figsize=(20, 10))
sns.histplot(data=df, x='age', hue='survived', kde=True, bins=30, palette='Blues')
plt.title('Survived Değişkenine Göre Yaş Dağılımı')
plt.xlabel('Yaş')
plt.ylabel('Kişi Sayısı')
plt.legend(title='Survived', labels=['Hayır (0)', 'Evet (1)'])
plt.show()
# Hayatta kalanlar genelde 20-30 yaş arası yaşlı nüfus az gelişmişlik az

# %% [markdown]
# ### ❓ Soru: Cinsiyet ve sınıfa göre hayatta kalma oranlarını barplot ile karşılaştırın.

# %%
df['pclass_sex'] = df['pclass'].astype(str) + "_" + df['sex']

sns.barplot(x="pclass_sex", y="survived", data=df) 
plt.title("Cinsiyet ve Sınıfa Göre Hayatta Kalma Orani") 
plt.xlabel("pclass_sex") 
plt.ylabel("survived") 
plt.xticks(rotation=90) 
plt.tight_layout() 
plt.show()

# %% [markdown]
# ### ❓ Soru: FacetGrid ile cinsiyete göre yaş histogramlarını ayrı ayrı gösterin.

# %%
g = sns.FacetGrid(df, col='sex', height=5, aspect=1)
g.map(sns.histplot, 'age', bins=20, color='salmon')
g.set_axis_labels('Yaş', 'Kişi Sayısı')
g.set_titles(col_template="{col_name}")

# %% [markdown]
# ### ❓ Soru: "Fare" ve "Age" değişkenleri arasında scatterplot oluşturun.

# %%
sns.scatterplot(x="fare", y="age", data=df) 
plt.title("Fare ve Age İlişkisi") 
plt.xlabel("Fare") 
plt.ylabel("Age") 
plt.show()

# %% [markdown]
# ### ❓ Soru: Korelasyon matrisi ve heatmap ile değişkenler arasındaki ilişkiyi görselleştirin.

# %%
corr_matrix = df[['age', 'fare', 'pclass', 'survived']].corr(method='pearson')
print(corr_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Korelasyon Matrisi Heatmap')
plt.show()
# Out:
#                age      fare    pclass  survived
# age       1.000000  0.096067 -0.369226 -0.077221
# fare      0.096067  1.000000 -0.549500  0.257307
# pclass   -0.369226 -0.549500  1.000000 -0.338481
# survived -0.077221  0.257307 -0.338481  1.000000

# %% [markdown]
# ## 🔴 İleri Seviye

# %% [markdown]
# ### ❓ Soru: "Age" değişkeninin çarpıklık (skewness) ve basıklığını (kurtosis) hesaplayın ve yorumlayın.

# %%
from scipy.stats import skew, kurtosis
age_skew = skew(df['age'].dropna())
age_kurt = kurtosis(df['age'].dropna())

print(f"Çarpıklık: {age_skew:.2f}")
print(f"Basıklık : {age_kurt:.2f}")
#çarpıklık > 0 sağa çarpık ortalama>medyan
#basıklık > 0 sivri dağılım , uç değerler çok fazla
# Out:
# Çarpıklık: 0.39
# Basıklık : 0.17

# %% [markdown]
# ### ❓ Soru: Seaborn pairplot ile sayısal değişkenleri inceleyin. Hayatta kalma durumunu hue parametresiyle ayırın.

# %%
numeric_cols = df.select_dtypes(include='number').columns
sns.pairplot(df[numeric_cols], hue='survived', corner=True, plot_kws={'alpha': 0.6})
plt.suptitle('Sayısal Değişkenler Arası İlişki ', y=1.02)
plt.show()
#hue parametresi hayatta kalma durumuna göre renk ayrımı yapar
#hue olmazsa yine bu grafikleri görürüz ama renkli değil sadece genel dağılımını görürürüz.

# %% [markdown]
# ### ❓ Soru: "Sex", "Pclass" ve "Survived" değişkenlerini içeren gruplu bir violinplot oluşturun.

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='pclass', y='age', hue='survived', data=df[df['sex'] == 'female'], split=True)
plt.title('Kadınlar için Pclass ve Survived’a Göre Yaş Dağılımı')
plt.show()

plt.figure(figsize=(12, 6))
sns.violinplot(x='pclass', y='age', hue='survived', data=df[df['sex'] == 'male'], split=True)
plt.title('Erkekler için Pclass ve Survived’a Göre Yaş Dağılımı')
plt.show()

# %% [markdown]
# ### ❓ Soru: "Embarked" değişkenine göre fare dağılımını inceleyin.

# %%
print(df.groupby("embarked")["fare"].describe())
print(df.groupby("embarked")["fare"].mean())
print(df.groupby("embarked")["fare"].median())
plt.figure(figsize=(8, 5))
sns.boxplot(x="embarked", y="fare", data=df)
plt.title("Embarked Değişkenine Göre Fare Dağılımı")
plt.xlabel("Emnarked")
plt.ylabel("Fare")
plt.show()
# her limandan binen yolcuların ücret dağılmını görürüz
# örneğin ortadaki limandakiler  (C) daha pahalıya bilet almış
# Out:
#           count       mean        std     min       25%    50%        75%  \
# embarked
# C         168.0  59.954144  83.912994  4.0125  13.69795  29.70  78.500025
# Q          77.0  13.276030  14.188047  6.7500   7.75000   7.75  15.500000
# S         644.0  27.079812  35.887993  0.0000   8.05000  13.00  27.900000
#
#                max
# embarked
# C         512.3292
# Q          90.0000
# S         263.0000
# embarked
# C    59.954144
# Q    13.276030
# S    27.079812
# Name: fare, dtype: float64
# embarked
# C    29.70
# Q     7.75
# S    13.00
# Name: fare, dtype: float64

# %% [markdown]
# ### ❓ Soru: Plotly ile cinsiyet ve sınıfa göre interaktif bir histogram oluşturun.

# %%
#ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
 #hatası alıyorum düzeltemedim 
df = sns.load_dataset("titanic")


fig = px.histogram(
    df,
    x="fare",
    color="sex",        
    facet_col="pclass", 
    nbins=30,
    title="Cinsiyet ve Sınıfa Göre Fare Dağılımı"
)

fig.update_layout(bargap=0.1)  
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 16
#       6 fig = px.histogram(
#       7     df,
#       8     x="fare",
#    (...)     12     title="Cinsiyet ve Sınıfa Göre Fare Dağılımı"
#      13 )
#      15 fig.update_layout(bargap=0.1)
# ---> 16 fig.show()
#
# File c:\Users\ceren\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:3420, in BaseFigure.show(self, *args, **kwargs)
#    3387 """
#    3388 Show a figure using either the default renderer(s) or the renderer(s)
#    3389 specified by the renderer argument
#    (...)   3416 None
#    3417 """
#    3418 import plotly.io as pio
# -> 3420 return pio.show(self, *args, **kwargs)
#
# File c:\Users\ceren\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
# ...

# %% [markdown]
# ### ❓ Soru: Eksik veri analizi yaparak eksik verileri heatmap ile görselleştirin.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
df = sns.load_dataset("titanic")
print(df.isnull().mean() * 100)
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap="viridis", yticklabels=False)
plt.title("Eksik Verilerin Heatmap ile Gösterimi")
plt.show()
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# ### ❓ Soru: Cinsiyet ve yaş arasındaki ilişkiyi scatterplot ile gösterip renkleri hayatta kalma durumuna göre ayarlayın.

# %%
# Cinsiyeti sayısal değere çevirelim (male=0, female=1)
df["Sex_num"] = df["sex"].map({"male": 0, "female": 1})

plt.figure(figsize=(10, 4))
sns.scatterplot(data=df, x="age", y="Sex_num", hue="survived", palette="husl")

plt.yticks([0, 1], ["Male", "Female"])
plt.title("Cinsiyet ve Yaş Arasındaki İlişki (Survived Renkli)")
plt.xlabel("Yaş")
plt.ylabel("Cinsiyet")
plt.show()

# %% [markdown]
# ### ❓ Soru: Matplotlib ile özelleştirilmiş bir bar grafiği oluşturun (renk, kalınlık, grid, label).

# %%
import pandas as pd
import matplotlib.pyplot as plt
fare_means = df.groupby("sex")["fare"].mean()

plt.figure(figsize=(8, 5))
bars = plt.bar(fare_means.index, fare_means.values, color=["hotpink", "salmon"], edgecolor="black", linewidth=2)

for bar in bars:
    y = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, y + 1, f"{y:.2f}", ha="center")

plt.title("Cinsiyete Göre Ortalama Bilet Ücreti")
plt.xlabel("Cinsiyet")
plt.ylabel("Ortalama Fare")
plt.grid(axis="y", linestyle="--", alpha=0.10)
plt.show()

# %% [markdown]
# ## 📘 Bonus Yorumlama Soruları

# %% [markdown]
# ### ❓ Soru: Korelasyonu yüksek olan iki değişken bulun. İlişkilerini grafikle açıklayın.

# %%
numeric_df = df.select_dtypes(include="number")

# Korelasyon matrisi
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
 # en yüksek ilişki fare ile pclass ikisinin arasında negatif bir ilişki var ve yüksek
corr_value = correlation_matrix.loc["fare", "pclass"]
print(f"Pclass ve Fare arasındaki korelasyon: {corr_value:.2f}")

plt.figure(figsize=(8, 5))
sns.regplot(x="pclass", y="fare", data=df, scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})

plt.title("Pclass ve Fare Arasındaki Korelasyon")
plt.xlabel("Pclass")
plt.ylabel("Fare")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()
# Out:
#           survived    pclass       age     sibsp     parch      fare   Sex_num
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307  0.543351
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500 -0.131900
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067 -0.093254
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651  0.114631
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225  0.245489
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000  0.182333
# Sex_num   0.543351 -0.131900 -0.093254  0.114631  0.245489  0.182333  1.000000
# Pclass ve Fare arasındaki korelasyon: -0.55

# %% [markdown]
# ### ❓ Soru: En fazla hayatta kalan grup hangisidir? (Cinsiyet + Sınıf)

# %%
survivor_counts = df.groupby(["sex", "pclass"])["survived"].sum()
print(survivor_counts)

survivor_counts = survivor_counts.unstack()  
survivor_counts.plot(kind="bar", figsize=(10, 6))
plt.title("Cinsiyet ve Sınıfa Göre Hayatta Kalan Sayısı")
plt.xlabel("Cinsiyet")
plt.ylabel("Hayatta Kalan Kişi Sayısı")
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.legend(title="Pclass")
plt.show()
# Out:
# sex     pclass
# female  1         91
#         2         70
#         3         72
# male    1         45
#         2         17
#         3         47
# Name: survived, dtype: int64

# %% [markdown]
# ### ❓ Soru: Yaş dağılımı normal mi? Neden?

# %%
plt.figure(figsize=(10,5))
sns.histplot(df["age"].dropna(), kde=True)
plt.title("Yaş Dağılımı Histogramı")
plt.xlabel("Yaş")
plt.ylabel("Frekans")
plt.show()
# histogram sağa doğru kuyruklu orta yaşlı yolcu fazla yaşlı az

# %% [markdown]
# ### ❓ Soru: Violinplot ile boxplot’ın farkı nedir?

# %%
#İkisi de aykırı değerleri gösterir .Ama violinplot daha detaylı analiz yapar.Boxplot daha hızlı çıktı verir.
#boxplot yığunluk bilgisi vermez
#boxplot sadece özet bilgi verir. ama violinplot hem özet bilgi hem istatistikler vhem de verinin dağılım yoğunluğunu gösterir.

# %% [markdown]
# ### ❓ Soru: Grafiklerde dikkat edilmesi gereken 3 temel ipucu nedir?

# %%
# Ne istenildiğini anlamak veriyi doğru grafikle göstermek
#grafiklerin eksenleri doğru ve uygun olsun 
#basit ve net olması

# %% [markdown]
# ## 🧠 Refleksiyon

# %% [markdown]
# **En çok şaşırdığınız veya dikkat çeken sonuç neydi? Görselleştirme size veriyle ilgili hangi içgörüleri sağladı?**

# %%
'''
Hue parametresinin  basit ama çok işlevsel olması dikkatimi çekti 
görselleştirme sayesinde verileri aklımda daha rahat canlandırabildim örneğin 
age ile survived ilişkisini düşününce
grafiği görmem daha akılda kalıcıydı 
verilerin arkasındaki örüntüleri gördüm
'''
# Out:
# '\nHue parametresinin  basit ama çok işlevsel olması dikkatimi çekti \ngörselleştirme sayesinde verileri aklımda daha rahat canlandırabildim örneğin age ile survived ilişkisini düşününce\ngrafiği görmem daha akılda kalıcıydı \nverilerin arkasındaki örüntüleri gördüm\n'
